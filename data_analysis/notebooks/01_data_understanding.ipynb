# %%
import pandas as pd
df = pd.read_excel("../data/raw/bc.xlsx")

df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 841 entries, 0 to 840
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STT         841 non-null    int64
#  1   Mã          841 non-null    str
#  2   Hàng        841 non-null    str
#  3   ĐVT         841 non-null    str
#  4   Tiền Nhập   841 non-null    int64
#  5   SL Xuất KM  841 non-null    int64
#  6   SL Xuất     841 non-null    int64
#  7   Tiền Xuất   841 non-null    int64
#  8   Doanh Thu   841 non-null    int64
#  9   Ngày Xuất   841 non-null    str
#  10  Khách hàng  841 non-null    str
# dtypes: int64(6), str(5)
# memory usage: 72.4 KB
#    STT       Mã                                               Hàng   ĐVT  \
# 0    1    KV100                  Khăn Napkin Toply 100 tờ x 48 gói   Gói
# 1    2      TLM  Tẩy toilet Liên Minh (nguyên liệu nhập khẩu) x...  Chai
# 2    3   NG3600     Nước giặt Kimono 6 in 1 (tím) x 3,6kg x 4 bình  Bình
# ...

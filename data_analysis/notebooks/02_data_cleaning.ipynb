# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.cleaning import clean_data

df = pd.read_excel("../data/raw/bc.xlsx")

df_clean = clean_data(df)

df_clean.to_csv("../data/cleaned/bc_cleaned.csv", index=False)

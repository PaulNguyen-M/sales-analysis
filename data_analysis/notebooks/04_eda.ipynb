# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.eda import *

df = pd.read_csv("../data/final/bc_final.csv")

print(revenue_by_product(df).head(10))
print(profit_by_product(df).head(10))
print(top_customers(df).head(10))
print(promotion_effect(df))
print(revenue_by_month(df))
# Out:
# Hang
# Khăn Napkin Toply 100 tờ x 48 gói               5330600
# Yến sào Seunest CĐ vàng x 6 hộp                 4692000
# Khăn Napkin TiOne nâu 100 tờ x 30 gói           1672000
# HIMA Seunest DTHT có đường 6 lọ x 6 hộp         1634000
# Khăn ướt Lovely (khổ lớn) 150g x 30 gói         1545000
# HIMA Seunest Colagen có đường 6 lọ x 6 hộp      1500000
# Khăn ướt TE Villa 250g x 30 gói                 1179500
# Khăn Napkin TiOne Gấu 100 tờ x 48 gói           1172000
# Khánh Hòa SmileNest Vàng ( CĐ) 6 lọ x 8 hộp     1136000
# Khánh Hòa SmileNest Đỏ ( Canxi) 6 lọ x 8 hộp    1136000
# Name: Doanh_Thu, dtype: int64
# Hang
# Khánh Hòa SmileNest Vàng ( CĐ) 6 lọ x 8 hộp           352000
# Khánh Hòa SmileNest Đỏ ( Canxi) 6 lọ x 8 hộp          352000
# HIMA Seunest Colagen có đường 6 lọ x 6 hộp            200000
# BC KAKA NANO N302 x 20 cây x 20 hộp                    67000
# BC KAKA NANO X6 x 20 x 15 lốc                          60000
# BC KAKA NANO N193 x 30 cây x 10 hộp                    57000
# BC KaKa Nhật N82 bộ 3 cây x 9 bộ x 33 túi              49500
# Yến sào Seunest Huyết x 6 hộp                          48000
# SRT tự nhiên (hồng, tím, đỏ, xanh) 500ml x 20 chai     20000
# A1 Yến sào có nhân sâm 70ml x 6 lọ x 6 hộp                 0
# Name: Profit, dtype: int64
# Khach_Hang
# Căn tin BV Phổi( Chị Duyên) - BV phổi    1971276
# Minh Hiền (chị Ớ) - B.H.Trung            1335960
# Tuấn Quyên - P.Thịnh                     1298000
# Nhung Nhựt - N.V.Tiếp                    1205000
# Xuân Bình - M.Hiệp                       1188000
# Chú 7 Vân - B.H.Tây                      1014984
# TT Hoàng Yến - M.Long                    1013184
# TH Trinh (Mỹ Trinh) - HCL (cuối chợ)      875856
# Sữa tả Hoàng Trúc - HCL (T.Mỹ)            833690
# Tuấn Kiệt - M.Long                        771755
# Name: Doanh_Thu, dtype: int64
# Promo
# False    54974.009804
# True    -60063.034934
# Name: Doanh_Thu, dtype: float64
# Month
# 1.0     1354200
# 2.0     -921108
# 3.0      452655
# 4.0     1325818
# 5.0    -1445061
# 6.0       94502
# 7.0     1533348
# 9.0      618604
# 10.0     591600
# 11.0    2096445
# 12.0     155000
# Name: Doanh_Thu, dtype: int64

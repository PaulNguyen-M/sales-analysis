# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.feature_engineering import add_features

df = pd.read_csv("../data/cleaned/bc_cleaned.csv")

df_feat = add_features(df)

df_feat.to_csv("../data/final/bc_final.csv", index=False)
